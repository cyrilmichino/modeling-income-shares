# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests

# %%
data = pd.read_csv("CollegeScoreData/MERGED2021_22_PP.csv")
data.head()
# Out:
# /var/folders/35/13d00tc92bb7m81x0w1lfh5r0000gn/T/ipykernel_5598/3417971657.py:1: DtypeWarning: Columns (9,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984,2403,2404,2495,2496,2497,2498,2499,2500,2501,2502,2503,2504,2505,2506,2507,2508,2509,2510,2511,2512,2513,2514,2515,2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530,3215,3231) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("CollegeScoreData/MERGED2021_22_PP.csv")
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Columns: 3232 entries, UNITID to ADDR
# dtypes: float64(2693), int64(13), object(526)
# memory usage: 161.3+ MB

# %%
data.describe()
# Out:
#              UNITID         OPEID        OPEID6  SCH_DEG         HCM2  \
# count  6.543000e+03  6.523000e+03   6523.000000      0.0  6543.000000
# mean   2.346034e+06  1.748939e+06  17014.133221      NaN     0.007030
# std    8.159248e+06  2.152323e+06  15181.014987      NaN     0.083559
# min    1.006540e+05  1.002000e+05   1002.000000      NaN     0.000000
# 25%    1.741315e+05  3.080505e+05   3072.500000      NaN     0.000000
# 50%    2.293370e+05  1.031904e+06  10198.000000      NaN     0.000000
# 75%    4.572395e+05  3.083350e+06  30780.000000      NaN     0.000000
# max    4.966450e+07  8.209882e+07  42991.000000      NaN     1.000000
#
#               MAIN    NUMBRANCH      PREDDEG      HIGHDEG      CONTROL  ...  \
# count  6543.000000  6543.000000  6543.000000  6543.000000  6543.000000  ...
# mean      0.794437     3.151001     1.831729     2.235825     2.066025  ...
# std       0.404143     6.916664     1.082061     1.376703     0.833739  ...
# ...

# %%
data_dict = pd.read_excel("CollegeScorecardDataDictionary.xlsx")
data_dict.head()
# Out:
# Traceback (most recent call last):
#
#   File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[12], line 1
#     data_dict = pd.read_excel("CollegeScorecardDataDictionary.xlsx")
#
#   File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:478 in read_excel
#     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#
#   File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:1483 in __init__
#     if import_optional_dependency("xlrd", errors="ignore") is None:
#
#   File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/compat/_optional.py:142 in import_optional_dependency
#     module = importlib.import_module(name)
#
# ...
